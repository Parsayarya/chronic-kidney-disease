# %% [markdown]
# <a href="https://colab.research.google.com/github/Parsayarya/chronic-kidney-disease/blob/main/chronic_kidney_disease0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('/content/DATASET.csv')
# df.isnull().sum()
# df = df.astype(int)
df
# Out:
#      Hospital  Age  Gender    BMI  ... Hemofilter Inotrope  Cr-1  Cr-7
# 0           2   67       2  24.77  ...          1        0  1.50  1.64
# 1           2   72       1  29.41  ...          1      NaN  1.30   0.9
# 2           2   58       2  25.16  ...          1      NaN  1.20   1.2
# 3           2   40       1  24.21  ...          1      NaN  1.50   1.7
# 4           2   58       2     30  ...          1      NaN  2.00   1.1
# ..        ...  ...     ...    ...  ...        ...      ...   ...   ...
# 387         3   55       2      _  ...          1        1  1.33  1.59
# 388         3   69       2  26.23  ...          1        0  1.17  1.12
# 389         3   74       1      _  ...          1        1  0.90  0.87
# 390         3   75       2  23.41  ...          1        0  1.53  1.21
# 391         3   46       1  27.34  ...          1        0  1.32  1.13
#
# [392 rows x 41 columns]

# %%
#getting rid of missing values sol 1
df1 = df.dropna()

# %%
#getting rid of missing values sol 2
df2 = df.fillna(axis=0, method='bfill')
df2.isnull().sum()
# Out:
# Hospital        0
# Age             0
# Gender          0
# BMI             0
# Surgery         0
# Type            0
# HTN             0
# DM              0
# CKD             0
# PHTN            0
# COPD            0
# Stenting        0
# CVA             0
# 3VD             0
# ACEI            0
# ARB             0
# BB              0
# Diuretics       0
# CCB             0
# Statin          0
# ASA             0
# NSAIDs          0
# EF              0
# Cr              0
# Alb             0
# BS              0
# A1C             0
# Hct             0
# Anestehsai      0
# Crystalloid     0
# Colloid         0
# Colloid type    0
# Colloid Dose    0
# P.C             0
# FFP             0
# Diuretic        0
# CPB time        0
# Hemofilter      0
# Inotrope        0
# Cr-1            0
# Cr-7            0
# dtype: int64

# %%
#getting rid of missing values sol 3
df3 = df.fillna(value=0)

# %%
print(df.columns)
print(df.isnull().sum())
# Out:
# Index(['Hospital', 'Age', 'Gender', 'BMI', 'Surgery', 'Type', 'HTN', 'DM',
#        'CKD', 'PHTN', 'COPD', 'Stenting', 'CVA', '3VD', 'ACEI', 'ARB', 'BB',
#        'Diuretics', 'CCB', 'Statin', 'ASA', 'NSAIDs', 'EF', 'Cr', 'Alb', 'BS',
#        'A1C', 'Hct', 'Anestehsai', 'Crystalloid', 'Colloid', 'Colloid type',
#        'Colloid Dose', 'P.C', 'FFP', 'Diuretic', 'CPB time', 'Hemofilter',
#        'Inotrope', 'Cr-1', 'Cr-7'],
#       dtype='object')
# Hospital          0
# Age               0
# Gender            0
# BMI              19
# Surgery           0
# Type              0
# HTN               1
# DM                1
# CKD               2
# PHTN              5
# COPD              1
# Stenting          1
# CVA               1
# 3VD               1
# ACEI              1
# ARB               1
# BB                1
# Diuretics         1
# CCB               1
# Statin            1
# ASA               1
# NSAIDs            2
# EF                2
# Cr                1
# ...

# %%
#getting rid of missing values sol 4
df4 = df.replace({ "_": np.nan,"__": np.nan,"_ ": np.nan," ": np.nan})
# df4['BMI'].fillna(int(df4['BMI'].mean()), inplace=True)
for col in df4.columns:
  for i in range(392):
    df4[col][i] = float(df4[col][i])
for col in df4.columns:
  df4[col].fillna(int(df4[col].mean()), inplace=True)
df4
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      Hospital  Age  Gender    BMI  ...  Hemofilter  Inotrope  Cr-1  Cr-7
# 0           2   67       2  24.77  ...           1       0.0  1.50  1.64
# 1           2   72       1  29.41  ...           1       0.0  1.30  0.90
# 2           2   58       2  25.16  ...           1       0.0  1.20  1.20
# 3           2   40       1  24.21  ...           1       0.0  1.50  1.70
# 4           2   58       2  30.00  ...           1       0.0  2.00  1.10
# ..        ...  ...     ...    ...  ...         ...       ...   ...   ...
# 387         3   55       2  26.00  ...           1       1.0  1.33  1.59
# 388         3   69       2  26.23  ...           1       0.0  1.17  1.12
# ...

# %%
df5 = df.replace({ "_": np.nan,"__": np.nan,"_ ": np.nan," ": np.nan,'_': np.nan})
for col in df5.columns:
  for i in range(392):
    df5[col][i] = float(df5[col][i])
for col in df5.columns:
  df5[col].fillna(float(np.random.choice(df5[col])), inplace=True)
# df5.fillna(0,inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
df5
# Out:
#      Hospital  Age  Gender    BMI  ...  Hemofilter  Inotrope  Cr-1  Cr-7
# 0           2   67       2  24.77  ...           1       0.0  1.50  1.64
# 1           2   72       1  29.41  ...           1       0.0  1.30  0.90
# 2           2   58       2  25.16  ...           1       0.0  1.20  1.20
# 3           2   40       1  24.21  ...           1       0.0  1.50  1.70
# 4           2   58       2  30.00  ...           1       0.0  2.00  1.10
# ..        ...  ...     ...    ...  ...         ...       ...   ...   ...
# 387         3   55       2  27.65  ...           1       1.0  1.33  1.59
# 388         3   69       2  26.23  ...           1       0.0  1.17  1.12
# 389         3   74       1  27.65  ...           1       1.0  0.90  0.87
# 390         3   75       2  23.41  ...           1       0.0  1.53  1.21
# 391         3   46       1  27.34  ...           1       0.0  1.32  1.13
#
# [392 rows x 41 columns]

# %%
df4
# Out:
#      Hospital  Age  Gender    BMI  ...  Hemofilter  Inotrope  Cr-1  Cr-7
# 0           2   67       2  24.77  ...           1       0.0  1.50  1.64
# 1           2   72       1  29.41  ...           1       0.0  1.30  0.90
# 2           2   58       2  25.16  ...           1       0.0  1.20  1.20
# 3           2   40       1  24.21  ...           1       0.0  1.50  1.70
# 4           2   58       2  30.00  ...           1       0.0  2.00  1.10
# ..        ...  ...     ...    ...  ...         ...       ...   ...   ...
# 387         3   55       2  26.00  ...           1       1.0  1.33  1.59
# 388         3   69       2  26.23  ...           1       0.0  1.17  1.12
# 389         3   74       1  26.00  ...           1       1.0  0.90  0.87
# 390         3   75       2  23.41  ...           1       0.0  1.53  1.21
# 391         3   46       1  27.34  ...           1       0.0  1.32  1.13
#
# [392 rows x 41 columns]

# %%
df4 = df4.drop(columns=["Day1Stamps","Day7Stamps"])
df5 = df5.drop(columns=["Day1Stamps","Day7Stamps"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-b888e2bb6312> in <module>()
# ----> 1 df4 = df4.drop(columns=["Day1Stamps","Day7Stamps"])
#       2 df5 = df5.drop(columns=["Day1Stamps","Day7Stamps"])
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4172             level=level,
#    4173             inplace=inplace,
# -> 4174             errors=errors,
#    4175         )
#    4176
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3887         for axis, labels in axes.items():
#    3888             if labels is not None:
# -> 3889                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3890
#    3891         if inplace:
#
# ...

# %%
#adding new stamps
day1=[None] * 392
day7=[None] * 392
label = [1,2,3,0]
for i in range(392):
  if ((df4['Cr-1'][i] > 0.3 + df4['Cr'][i] or df4['Cr'][i] * 1.5 < df4['Cr-1'][i] < df4['Cr'][i] * 1.9)):
    day1[i] = label[0]
  elif ((df4['Cr'][i] * 2 < df4['Cr-1'][i] < df4['Cr'][i] * 2.9)):
    day1[i] = label[1]
  elif ((df4['Cr'][i] * 3 < df4['Cr-1'][i] or df4['Cr-1'][i] > 4)):
    day1[i] = label[2]
  elif (( df4['Cr-1'][i] <= df4['Cr'][i] or df4['Cr-1'][i] < 0.3 + df4['Cr'][i] or df4['Cr-1'][i] < 1.5 * df4['Cr'][i])):
    day1[i] = label[3]
for i in range(392):
  if (df4['Cr-7'][i] > 0.3 + df4['Cr'][i] or df4['Cr'][i] * 1.5 < df4['Cr-7'][i] < df4['Cr'][i] * 1.9):
        day7[i] = label[0]
  elif (df4['Cr'][i] * 2 < df4['Cr-7'][i] < df4['Cr'][i] * 2.9):
        day7[i] = label[1]
  elif (df4['Cr'][i] * 3 < df4['Cr-7'][i] or df4['Cr-7'][i] > 4):
        day7[i] = label[2]
  elif (df4['Cr-7'][i] <= df4['Cr'][i] or df4['Cr-7'][i] < 0.3 + df4['Cr'][i] or df4['Cr-7'][i] < 1.5 * df4['Cr'][i]):
        day7[i] = label[3]

# %%
#adding new stamps
Rday1=[None] * 392
Rday7=[None] * 392
Rlabel = ['stamp1','stamp2','stamp3','stamp0']
for i in range(392):
  if ((df5['Cr-1'][i] > 0.3 + df5['Cr'][i] or df5['Cr'][i] * 1.5 < df5['Cr-1'][i] < df5['Cr'][i] * 1.9)):
    Rday1[i] = label[0]
  elif ((df5['Cr'][i] * 2 < df5['Cr-1'][i] < df5['Cr'][i] * 2.9)):
    Rday1[i] = label[1]
  elif ((df5['Cr'][i] * 3 < df5['Cr-1'][i] or df5['Cr-1'][i] > 4)):
    Rday1[i] = label[2]
  elif (( df5['Cr-1'][i] <= df5['Cr'][i] or df5['Cr-1'][i] < 0.3 + df5['Cr'][i] or df5['Cr-1'][i] < 1.5 * df5['Cr'][i])):
    Rday1[i] = label[3]
for i in range(392):
  if (df5['Cr-7'][i] > 0.3 + df5['Cr'][i] or df5['Cr'][i] * 1.5 < df5['Cr-7'][i] < df5['Cr'][i] * 1.9):
        Rday7[i] = label[0]
  elif (df5['Cr'][i] * 2 < df5['Cr-7'][i] < df5['Cr'][i] * 2.9):
        Rday7[i] = label[1]
  elif (df5['Cr'][i] * 3 < df5['Cr-7'][i] or df5['Cr-7'][i] > 4):
        Rday7[i] = label[2]
  elif (df5['Cr-7'][i] <= df5['Cr'][i] or df5['Cr-7'][i] < 0.3 + df5['Cr'][i] or df5['Cr-7'][i] < 1.5 * df5['Cr'][i]):
        Rday7[i] = label[3]

# %%
df4['Day1Stamps'] = day1
df4['Day7Stamps'] = day7

# %%
df5['Day1Stamps'] = Rday1
df5['Day7Stamps'] = Rday7

# %%
pd.set_option('display.max_rows', len(df4))
print(df4)
pd.reset_option('display.max_rows')
# Out:
#      Hospital  Age  Gender    BMI  ...  Cr-1  Cr-7  Day1Stamps  Day7Stamps
# 0           2   67       2  24.77  ...  1.50  1.64           0           0
# 1           2   72       1  29.41  ...  1.30  0.90           0           0
# 2           2   58       2  25.16  ...  1.20  1.20           0           0
# 3           2   40       1  24.21  ...  1.50  1.70           0           0
# 4           2   58       2  30.00  ...  2.00  1.10           1           0
# 5           2   70       2  18.36  ...  1.10  0.90           0           0
# 6           2   60       1  17.33  ...  1.00  1.00           0           0
# 7           2   72       2  26.59  ...  1.20  1.40           0           0
# 8           2   54       2  27.11  ...  1.70  1.50           0           0
# 9           2   56       2  30.00  ...  1.50  1.20           0           0
# 10          2   18       2  30.09  ...  0.90  1.00           0           0
# ...

# %%
pd.set_option('display.max_rows', len(df5))
print(df5)
pd.reset_option('display.max_rows')
# Out:
#      Hospital  Age  Gender    BMI  ...  Cr-1  Cr-7  Day1Stamps  Day7Stamps
# 0           2   67       2  24.77  ...  1.50  1.64           0           0
# 1           2   72       1  29.41  ...  1.30  0.90           0           0
# 2           2   58       2  25.16  ...  1.20  1.20           0           0
# 3           2   40       1  24.21  ...  1.50  1.70           0           0
# 4           2   58       2  30.00  ...  2.00  1.10           1           0
# 5           2   70       2  18.36  ...  1.10  0.90           0           0
# 6           2   60       1  17.33  ...  1.00  0.70           0           0
# 7           2   72       2  26.59  ...  1.20  1.40           0           0
# 8           2   54       2  27.11  ...  1.70  1.50           0           0
# 9           2   56       2  30.00  ...  1.50  1.20           0           0
# 10          2   18       2  30.09  ...  0.90  1.00           0           0
# ...

# %%
from sklearn.model_selection import train_test_split
X = df4.copy(deep= True)
X = X.drop(columns=["Day1Stamps","Day7Stamps"])
y = [[0]*392]*2
y[0],y[1] = df4['Day1Stamps'],df4["Day7Stamps"]
# X_train, X_test, y_train, y_test = train_test_split()

# %%
y
# Out:
# [0      0
#  1      0
#  2      0
#  3      0
#  4      1
#        ..
#  387    0
#  388    0
#  389    0
#  390    0
#  391    0
#  Name: Day1Stamps, Length: 392, dtype: int64, 0      0
#  1      0
#  2      0
#  3      0
#  4      0
#        ..
#  387    0
#  388    0
#  389    0
#  390    0
#  391    0
#  Name: Day7Stamps, Length: 392, dtype: int64]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y[0],test_size = 0.2)

# %%
X_1 = df5.copy(deep= True)
X_1 = X_1.drop(columns=["Day1Stamps","Day7Stamps"])
y_1 = [[0]*392]*2
y_1[0],y_1[1] = df5['Day1Stamps'],df5["Day7Stamps"]

# %%
X_train_1, X_test_1, y_train_1, y_test_1 = train_test_split(X_1,y_1[0],test_size = 0.2)

# %%
y_test
# Out:
# 198    0
# 121    0
# 92     1
# 87     0
# 5      0
#       ..
# 325    0
# 61     1
# 301    0
# 64     0
# 100    0
# Name: Day1Stamps, Length: 79, dtype: int64

# %% [markdown]
# **Training The Models**

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.metrics import roc_curve

# %%
model1 = DecisionTreeClassifier()

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

# %%
def avgl(lst):
    return sum(lst) / len(lst)
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.model_selection import StratifiedKFold
skfolds = StratifiedKFold(5)
precision = []
f_score = []
recall = []
accuracy = []
fpr = []
tpr = []
thresh = []
cnf_mx = []
y_predict = []
for train_index , val_index in skfolds.split(X_train , y_train):
  model1.fit(X_train.iloc[train_index] , y_train.iloc[train_index])
  y_prd = model1.predict(X_train.iloc[val_index])
  y_predict.append(y_prd)
  f = f1_score(y_train.iloc[val_index] , y_prd,average='weighted')
  p = precision_score(y_train.iloc[val_index] , y_prd,average='weighted')
  r = recall_score(y_train.iloc[val_index] ,y_prd,average='weighted' )
  a = accuracy_score(y_train.iloc[val_index], y_prd)
  fprr,tprr,threshh = roc_curve(y_train.iloc[val_index] , y_prd,pos_label=1)
  fpr.append(fprr)
  tpr.append(tprr)
  thresh.append(threshh)
  precision.append(p)
  f_score.append(f)
  recall.append(r)
  accuracy.append(a)
  cnf = confusion_matrix(y_prd, y_train.iloc[val_index])
  cnf_mx.append(cnf)
  # print(cnf_mx)
print(avgl(precision),"\t",avgl(f_score),"\t",avgl(recall),"\t",avgl(accuracy),"\t")
# print(type(fpr[0]))
# print(fpr[0])
print(fpr)
print(tpr)
# fpr = np.array(fpr)
# row_sum1 = fpr.sum(axis = 0)
# norm_fpr_mx = fpr / row_sum1
# norm_fpr_mx = norm_fpr_mx.reshape(5,4)
# f= 4*[0]
# for i in range(5):
#   f = f + norm_fpr_mx[i]
# f = f/5
# tpr = np.array(tpr)
# row_sum2 = tpr.sum(axis = 0 , keepdims = True)
# norm_tpr_mx = tpr / row_sum2
# norm_tpr_mx = norm_tpr_mx.reshape(5,4)
# t= 4*[0]
# for i in range(5):
#   t = t + norm_tpr_mx[i]
# t = t/5
# print(f,t)
# plt.plot(f , t , linewidth = 2 , color = 'red')
# plt.plot([0,1],[0,1] , 'k--')
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# print(cnf_mx)
# cnf_mx = np.array(cnf_mx)
# row_sum = cnf_mx.sum(axis = 1 , keepdims = True)
# norm_cnf_mx = cnf_mx / row_sum
# norm_cnf_mx = norm_cnf_mx.reshape(5,9)
# k= 9*[0]
# for i in range(5):
#   k = k + norm_cnf_mx[i]
# k = k/5
# k1 = 4*[0]
# for i in range(3):
#   k1[i]= k[i]
# k1 = np.asarray(k1)
# k1 = k1.reshape(2,2)
# plt.imshow(k1 , cmap= plt.cm.gray)
# print("TP:",k[0][0],"\t","TN:",k[0][1],"\t","FP:",k[1][0],"\t","FN:",k[1][1])
# for clf in classifiers:
#     clf.fit(X_train, y_train)
#     name = clf.__class__.__name__
    
#     print("="*30)
#     print(name)
#     try:
#         print('****Results****')
#         train_predictions = clf.predict(X_test)
#         acc = accuracy_score(y_test, train_predictions)
#         print(acc)
#         print(precision_score(y_test, train_predictions))
#         print(f1_score(y_test, train_predictions))
#         print(confusion_matrix(y_test, train_predictions))
#         print(log_loss(y_test, train_predictions))
#         log_entry = pd.DataFrame([[name, acc*100, log_loss(y_test, train_predictions)]], columns=log_cols)
#         log = log.append(log_entry)
#     except Exception as e:
#         print (e)
    
print(cnf_mx)
# Out:
# 0.8977873592553518 	 0.8973094956206911 	 0.8976446492575525 	 0.8976446492575525
# [array([0.        , 0.01851852, 0.09259259, 1.        ]), array([0.        , 0.01886792, 0.05660377, 1.        ]), array([0.        , 0.03703704, 0.09259259, 1.        ]), array([0.        , 0.01886792, 0.0754717 , 1.        ]), array([0.        , 0.01886792, 0.09433962, 1.        ])]
# [array([0.        , 0.        , 0.77777778, 1.        ]), array([0. , 0. , 0.8, 1. ]), array([0.        , 0.        , 0.55555556, 1.        ]), array([0.        , 0.        , 0.55555556, 1.        ]), array([0.        , 0.        , 0.55555556, 1.        ])]
# [array([[49,  2,  0],
#        [ 4,  7,  0],
#        [ 0,  0,  1]]), array([[50,  2,  0],
#        [ 2,  8,  0],
#        [ 0,  0,  1]]), array([[49,  4,  0],
#        [ 3,  5,  0],
#        [ 0,  0,  2]]), array([[49,  4,  0],
#        [ 3,  5,  0],
#        [ 0,  0,  1]]), array([[48,  4,  0],
#        [ 4,  5,  0],
#        [ 0,  0,  1]])]

# %%
fpr = np.array(fpr)
row_sum1 = fpr.sum(axis = 0)
norm_fpr_mx = fpr / row_sum1
norm_fpr_mx = norm_fpr_mx.reshape(5,4)
for i in range(5):
  norm_fpr_mx[i][0]=1
print(norm_fpr_mx)
f= 4*[0]
for i in range(5):
  f = f + norm_fpr_mx[i]
f = f/5
# f[2] = 0
# f[3] = 0
# Out:
# [[1.         0.16510903 0.22495756 0.2       ]
#  [1.         0.1682243  0.13752122 0.2       ]
#  [1.         0.33021807 0.22495756 0.2       ]
#  [1.         0.1682243  0.18336163 0.2       ]
#  [1.         0.1682243  0.22920204 0.2       ]]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
tpr = np.array(tpr)
row_sum2 = tpr.sum(axis = 0)
norm_tpr_mx = tpr / row_sum2
norm_tpr_mx = norm_tpr_mx.reshape(5,4)
for i in range(5):
  norm_tpr_mx[i][1]=1
  norm_tpr_mx[i][0]=1
print(norm_tpr_mx)
t= 4*[0]
for i in range(5):
  t = t + norm_tpr_mx[i]
t = t/5
# t[2]=0
# t[3] = 0
# Out:
# [[1.         1.         0.23972603 0.2       ]
#  [1.         1.         0.24657534 0.2       ]
#  [1.         1.         0.17123288 0.2       ]
#  [1.         1.         0.17123288 0.2       ]
#  [1.         1.         0.17123288 0.2       ]]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
plt.plot(f , t , linewidth = 2 , color = 'red')
plt.plot([0,1],[0,1] , 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
# Out:
# Text(0, 0.5, 'True Positive Rate')

# %%
cnf_mx = np.array(cnf_mx)
row_sum = cnf_mx.sum(axis = 1 , keepdims = True)
norm_cnf_mx = cnf_mx / row_sum
norm_cnf_mx = norm_cnf_mx.reshape(5,9)
k= 9*[0]
for i in range(5):
  k = k + norm_cnf_mx[i]
k = k/5
k = k.reshape(3,3)
print(k[0:2][0:2])
plt.imshow(k[0:2][0:2] , cmap= plt.cm.gray)
# Out:
# [[0.93875181 0.35111111 0.        ]]

# %%
skfolds = StratifiedKFold(5)
precision = []
f_score = []
recall = []
accuracy = []
for train_index , val_index in skfolds.split(X_train_1 , y_train_1):
  model1.fit(X_train_1.iloc[train_index] , y_train_1.iloc[train_index])
  y_prd = model1.predict(X_train_1.iloc[val_index])
  f = f1_score(y_train_1.iloc[val_index] , y_prd,average='weighted')
  p = precision_score(y_train.iloc[val_index] , y_prd,average='weighted')
  r = recall_score(y_train_1.iloc[val_index] ,y_prd,average='weighted' )
  a = accuracy_score(y_train_1.iloc[val_index], y_prd)
  precision.append(p)
  f_score.append(f)
  recall.append(r)
  accuracy.append(a)
print(avgl(precision),"\t",avgl(f_score),"\t",avgl(recall),"\t")
# Out:
# 0.7241936594902094 	 0.7368557178732928 	 0.8083461341525856 	 0.8083461341525856
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
skfolds = StratifiedKFold(5)
precision = []
f_score = []
recall = []
accuracy = []
for train_index , val_index in skfolds.split(X_train , y_train):
  model1.fit(X_train.iloc[train_index] , y_train.iloc[train_index])
  y_prd = model1.predict(X_train.iloc[val_index])
  f = f1_score(y_train.iloc[val_index] , y_prd,average='weighted')
  p = precision_score(y_train.iloc[val_index] , y_prd,average='weighted')
  r = recall_score(y_train.iloc[val_index] ,y_prd,average='weighted' )
  a = accuracy_score(y_train.iloc[val_index], y_prd)
  precision.append(p)
  f_score.append(f)
  recall.append(r)
  accuracy.append(a)
print(avgl(precision),"\t",avgl(f_score),"\t",avgl(recall),"\t",avgl(accuracy),"\t")
# Out:
# 0.8405536508355992 	 0.8756355790338886 	 0.913773681515617 	 0.913773681515617
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
skfolds = StratifiedKFold(5)
precision = []
f_score = []
recall = []
accuracy = []
for train_index , val_index in skfolds.split(X_train_1 , y_train_1):
  model1.fit(X_train_1.iloc[train_index] , y_train_1.iloc[train_index])
  y_prd = model1.predict(X_train_1.iloc[val_index])
  f = f1_score(y_train_1.iloc[val_index] , y_prd,average='weighted')
  p = precision_score(y_train.iloc[val_index] , y_prd,average='weighted')
  r = recall_score(y_train_1.iloc[val_index] ,y_prd,average='weighted' )
  a = accuracy_score(y_train_1.iloc[val_index], y_prd)
  precision.append(p)
  f_score.append(f)
  recall.append(r)
  accuracy.append(a)
print(avgl(precision),"\t",avgl(f_score),"\t",avgl(recall),"\t")
# Out:
# 0.8417308252757681 	 0.8740107212185114 	 0.910547875064004
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...
